# %% [markdown]
# ### line

# %%
str1 = "This is a laptop.\nit is very useful device."
print (str1)
# Out:
# This is a laptop.
# it is very useful device.

# %% [markdown]
# ### tap

# %%
str1 = "This is My physics book.\t It is full of knowledge"
print (str1)
# Out:
# This is My physics book.	 It is full of knowledge

# %% [markdown]
# ### concatenation

# %%
str1 ="car"
str2 ="washing"
sum = str1 + str2
print(sum)
# Out:
# carwashing

# %%
str1 = "badminton"
len1 = len(str1)
str2 = "Raket"
len2 = len(str2)
print ("length of 1st:",len1)
print ("length of 2nd:",len2)
# Out:
# length of 1st: 9
# length of 2nd: 5

# %% [markdown]
# ### Slicing

# %%
str = "al azhar"
print (str[-6:-2])
# Out:
#  azh

# %% [markdown]
# ### endswith

# %%
str = "There are many people going to bazar"
print (str.endswith("zar"))
# Out:
# True

# %% [markdown]
# ### Capitalizating

# %%
str = "i am your friend"
str = str.capitalize()
print (str)
# Out:
# I am your friend

# %% [markdown]
# ### replace

# %%
str = "I am studing education from sahara"
print (str.replace("sahara","Al Azhar"))
# Out:
# I am studing education from Al Azhar

# %% [markdown]
# ### Finding A value

# %%
str = "I am studing education from sahara"
print (str.find("r"))
# Out:
# 24

# %%
str = "I am from my home"
print (str.find("home"))
# Out:
# 13

# %%
name = input("enter your name :")
print("length of my name :",len(name))
# Out:
# enter your name :Horain
# length of my name : 6

# %%
str = "Hi Iam $ my name $ I live in $"
print (str.count("$"))
# Out:
# 3

# %%
Marks = int (input("Enter the number"))

if(Marks == 90):
  print("Garde A :")
elif(Marks==80):
  print("Grade B")
elif(Marks==70):
  print("Grade C")
else:
  print("Fail")
# Out:
# Enter the number54
# Fail

# %%
a = int (input("Enter the 1st Value :"))
b = int (input("Enter the 2nd Value :"))
c= int (input("Chose 1 for + 2 for -  3 for * 4 for / :") )
if(c==1) :
    print("sum",(a+b))
elif(c==2):
    print("Diff",(a-b))
elif(c==3):
    print("Product",(a*b))
elif(c==4):
    print("Division",(a/b))
else:
  print("please enter the value from 1 to 4")
# Out:
# Enter the 1st Value :10
# Enter the 2nd Value :5
# Chose 1 for + 2 for -  3 for * 4 for / :4
# Division 2.0

# %%
marks = [45 ,47,478,4848,4848,45445454,]

print(marks[0])
# Out:
# 45

# %%
list = [1,2,4,5,8,7]
list.pop(2)
print (list)
# Out:
# [1, 2, 5, 8, 7]

# %%
tub = (1, 4, 4, 3, )

print (tub.count(4))
# Out:
# 2
