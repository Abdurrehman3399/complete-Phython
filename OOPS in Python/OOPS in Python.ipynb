# %%
class Student:
    name = "SAAD"

s1 = Student()


print(s1.name)
# Out:
# SAAD

# %%
class Car:
    color = "Blue"
    Brand = "Toyota"


car1 = Car()
print (car1.color)
print (car1.Brand)
# Out:
# Blue
# Toyota

# %%
class student:
    name = "Azan"
    def __init__(self):
        
        print ("Adding a new Student named Shahzeb..")

        

s1 = student
