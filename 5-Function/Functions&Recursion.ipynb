# %%
def sum (a,b):
    c = a+b
    return c

# %%
sum(4,5)
# Out:
# 9

# %%
def solution (a,b): # Parameters
    return a+b 

solution(45,45) # Arguments
# Out:
# 90

# %%
def Name ():
    print("Abur-Rehman Javed")




Name()
Name()
Name()
Name()
Name()
# Out:
# Abur-Rehman Javed
# Abur-Rehman Javed
# Abur-Rehman Javed
# Abur-Rehman Javed
# Abur-Rehman Javed

# %%
def sum (a,b,c):
    d = a+b+c
    average = d/3
    return average

# %%
sum(45,85,45)
# Out:
# 58.333333333333336

# %%
print("Abdur-Rehman",end= " ")
print ("Javed")
# Out:
# Abdur-Rehman Javed

# %%
def show (n):
    if (n == 0):
        return
    print (n)
    show (n-1)
    print ("End")

show(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# End
# End
# End
# End
# End

# %%
def fact (n):
    if(n==0 or n==1):
        return 1
    return fact(n-1) * n


print(fact(5))
# Out:
# 120
