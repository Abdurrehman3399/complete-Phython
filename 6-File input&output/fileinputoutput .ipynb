# %%
f = open ("demo.txt", "r")
data = f.read()
print (data)
line1 = f.readline()
print (line1)
print (type(line1))
f.close()
# Out:
# I am Abdurrehman
# from Class 9th C
# My father is not a doctor.
#
#
# <class 'str'>

# %%
f = open ("demo.txt","w")
f.write("I am not your friend 123")
# Out:
# 24

# %%
f = open ("demo.txt","a")
f.write("/nI went to be a good guy.")
# Out:
# 26

# %%
f = open ("demo.txt","w")
f.write("Hi I am your Friend")
# Out:
# 19

# %%
f = open ("demo.txt","a")
f.write("\nMy age is 16")
# Out:
# 13

# %%
f = open ("demo.txt","r+")
f.write("\nhi threre I am Your best Teacher")
f.close()

# %%
f = open ("demo.txt","w+")
f.write ("Empty")
# Out:
# 5

# %%
f = open ("demo.txt","a+")
f.write (",Full")
# Out:
# 5

# %%
with open("demo.txt","r") as f:
    data = f.read()
    print(data)
# Out:
# THis is a demo file For Y
# and I am fine.

# %%
import os
os.remove("sample.txt")
