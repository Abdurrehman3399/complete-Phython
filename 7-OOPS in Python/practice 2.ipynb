# %% [markdown]
# Python Inheritance Question (4 Classes)
#
# Hospital Management System
#
# Create these 4 classes using inheritance.
#
#
# ---
#
# 1. Class Hospital
#
# Attributes:
#
# hospital_name
#
# city
#
#
#
# ---
#
# 2. Class Doctor
#
# Inherit from Hospital
#
# Add:
#
# doctor_name
#
# specialization
#
#
#
# ---
#
# 3. Class Patient
#
# Inherit from Doctor
#
# Add:
#
# patient_name
#
# disease
#
#
#
# ---
#
# 4. Class Treatment
#
# Inherit from Patient
#
# Add:
#
# medicine
#
#
#
# ---
#
# Task
#
# Create an object and display:
#
# Hospital Name
#
# City
#
# Doctor Name
#
# Specialization
#
# Patient Name
#
# Disease
#
# Medicine
#
#
#
# ---
#
# Example Output
#
# Hospital Name: City Hospital
# City: Lahore
# Doctor Name: Ahmed
# Specialization: Heart Specialist
# Patient Name: Ali
# Disease: Fever
# Medicine: Panadol
#
#
# ---
#
# Bonus Task
#
# Add a method show_details() in the last class to print all information.

# %%
class hospital :
  def __init__(self,hospital_name,city):
    self.hospital_name = hospital_name
    self.city = city
class doctor(hospital):
  def __init__(self, hospital_name, city,doctor_name,specilization):
    super().__init__(hospital_name, city)
    self.doctor_name = doctor_name
    self.specilization = specilization
class patient (doctor):
  def __init__(self, hospital_name, city, doctor_name, specilization,patient_name,disease):
    super().__init__(hospital_name, city, doctor_name, specilization)
    self.patient_name = patient_name
    self.disease = disease
class treatment (patient):
  def __init__(self, hospital_name, city, doctor_name, specilization, patient_name, disease,madicine):
    super().__init__(hospital_name, city, doctor_name, specilization, patient_name, disease)
    self.madicine = madicine
  def display (self):
    print("Hospital Name" , self.hospital_name)
    print("City" , self.city)
    print("Doctor Name" , self.doctor_name)
    print("Specilization" , self.specilization)
    print("Patient" , self.patient_name)
    print("Disease" , self.disease)
    print("Medicine" , self.madicine)

p1 = treatment ("City Hospital" , "Lahore" , "Ahmed" , "Heart Specilist" , "Ali" , "Fever" , "Panadol")
p1.display()
# Out:
# Hospital Name City Hospital
# City Lahore
# Doctor Name Ahmed
# Specilization Heart Specilist
# Patient Ali
# Disease Fever
# Medicine Panadol
