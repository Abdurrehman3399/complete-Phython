# %%
class Student:
    name = "SAAD"

s1 = Student()


print(s1.name)
# Out:
# SAAD

# %%
class Car:
    color = "Blue"
    Brand = "Toyota"


car1 = Car()
print (car1.color)
print (car1.Brand)
# Out:
# Blue
# Toyota

# %%
class student:
    name = "Azan"
    def __init__(self):
        
        print ("Adding a new Student named Shahzeb..")

        

s1 = student()
# Out:
# Adding a new Student named Shahzeb..

# %%
class Student :
    def __init__(Abcd, fullname):
        Abcd.name = fullname
        print("Addition of new Student..")

s1 =Student("Azan Khan")
print (s1.name)
# Out:
# Addition of new Student..
# Azan Khan

# %%
class Student :
    college_name = "Al Azhar"
    def __init__(self, fullname):
        self.name = fullname
        print("Addition of new Student..")

s1 =Student("Azan Khan")
print (s1.name)         

s2 =Student("Aman Khan")
print(s2.name)

s3 =Student("Arman Khan")
print(s3.name)

print (s3.college_name)
# Out:
# Addition of new Student..
# Azan Khan
# Addition of new Student..
# Aman Khan
# Addition of new Student..
# Arman Khan
# Al Azhar

# %%
class Ss:
    name = "ABC"

    def __init__(self,name):
        self.name = name


    def welcome(self):
        print("BY Student,",self.name)


s1 = Ss("Anonymous")
s1.welcome()
# Out:
# BY Student, Anonymous

# %%
class Ss:
    def __init__(self,name):
        self.name = name

s1 = ("Ali")
print(s1)
del s1.name
print (s1.name)
# Out:
# Ali
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       3         self.name = name
#       4
#       5 s1 = ("Ali")
#       6 print(s1)
# ----> 7 del s1.name
#       8 print (s1.name)
#       9
#
# AttributeError: 'str' object has no attribute 'name' and no __dict__ for setting new attributes

# %%
class Account:
    def __init__(self,acc_no,acc_pass):
        self.acc_no=acc_no
        self.acc_pass=acc_pass

    def reset_pass(self):
        print(acc1.reset_pass)
    
            

acc1=Account("abcd","123456798")
print(acc1.acc_no)
print(acc1.reset_pass())
# Out:
# abcd
# <bound method Account.reset_pass of <__main__.Account object at 0x000001E06ABE52B0>>
# None

# %%
class Car:

   @staticmethod
   def start ():
      print("To Start the car..") 
    
    
   @staticmethod
   def start ():
      print("To Stop the car..")

class ToyataCar(Car):
   def __init__(self,name):
      self.name = name
   
car1= ToyataCar("Furtuner")   
car2= ToyataCar("Prius")
print(car1.start())
# Out:
# To Stop the car..
# None

# %%
class Furtuner(ToyataCar):
    def __init__ (self,model):
        self.model = model
car1 = Furtuner("Desil")
car2 = Furtuner ("Electric")


print(car2.model)
# Out:
# Electric

# %%
class Person:
    name = "Anonymus"

def __init__(self, name):
    self.name = name 

p1 = Person()

print(p1.name)
# Out:
# Anonymus

# %%
class Person:
    name = "Anonymus"

    @classmethod

    def changeName(cls, name):
        cls.name = name





p1 = Person()
p1.changeName("Ali Khan")
print(p1.name)
print(Person.name)
# Out:
# Ali Khan
# Ali Khan

# %%
class Ss:
    def __init__(self,phy,che,bio,math):
        self.phy = phy
        self.math = math
        self.che = che
        self.bio = bio
        self.percentage = str((self.phy+ self.math+ self.che+ self.bio) / 4) + "%"

stu1 = Ss(45,44,55,47)
print (stu1.percentage)
# Out:
# 47.75%

# %%
class Ss:
    def __init__(self,phy,che,math):
        self.phy = phy
        self.math = math
        self.che = che
         

    @property
    def percentage(self):
        return str ((self.phy+ self.che+ self.math) / 3) + "%"
    
stu1 = Ss(45, 64, 45)
print (stu1.percentage)

stu1.math = 98
print(stu1.percentage)
# Out:
# 51.333333333333336%
# 69.0%

# %%
class complex:
    def __init__(self,real,img):
        self.img = img
        self.real = real

    def shownumber(self):
        print(self.real,"i" , self.img, "j")

num1 = complex(1,3)
num1.shownumber()

num2 = complex(4,7)
num2.shownumber()
# Out:
# 1 i 3 j
# 4 i 7 j

# %%
class complex:
    def __init__(self,real,img):
        self.img = img
        self.real = real

    def shownumber(self):
        print(self.real,"i" , self.img, "j")

    def __add__(self, num2):
        newReal = self.real +num2.real
        newImg = self.img + num2.img
        return complex(newReal,newImg)
       

num1 = complex(1,3)
num1.shownumber()

num2 = complex(4,7)
num2.shownumber()

# num3 = num1.add(num2)
# num3.shownumber()
num3 = num1 + num2
num3.shownumber()
# Out:
# 1 i 3 j
# 4 i 7 j
# 5 i 10 j
