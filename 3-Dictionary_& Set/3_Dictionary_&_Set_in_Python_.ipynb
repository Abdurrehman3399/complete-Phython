# %%
dic = {
    "name" : "Abdurrehman",
    "class" :"9th",
    "School" : "Al Azhar",
    "Days" : "9",
    "Age" : "True",
    "Marks" : "23.99",
    "topics" : ("Maths , Eng"),
    "Subjects" : ["bio , physics"]
}
print(type(dic))
# Out:
# <class 'dict'>

# %%
dic ={
"name" : "Abdurrehman",
"class" : {
       "phy" : "83",
       "che" : "75",
       "bio" :"99" ,
}
}
# Out:
# Abdurrehman

# %%
print(dic.keys())
# Out:
# dict_keys(['name', 'class'])

# %%
dic.update ({"Address" : "swat"})
print (dic)
# Out:
# {'name': 'Abdurrehman', 'class': {'phy': '83', 'che': '75', 'bio': '99'}, 'Address': 'swat'}

# %%
set = {34 , 45, 54, 50,53}
print (set)
print (type(set))
# Out:
# {34, 50, 53, 54, 45}
# <class 'set'>

# %%
set.add(50)
set.add(50)
set.add(55)
set.add(57)
set.add(55)
print (set)
set.remove(45)
# Out:
# {34, 50, 53, 54, 55, 57, 45}

# %%
set.clear()
print(set)
# Out:
# set()

# %%
set1 = {1, 2, 3}
set2 = {3 ,4, 5}
print (set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1, 2, 3}
set2 = {3 ,4, 5}
print (set1.intersection(set2))
# Out:
# {3}
