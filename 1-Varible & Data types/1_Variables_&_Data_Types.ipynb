# %% [markdown]
# ### varibles

# %%
name = "Abdurrehman"
age = "16"
price = "34.88"
print(name)
print (age)
print (price)
print ("my name is : " , name)
print ("my age is : " , age)

# %% [markdown]
# ### types find

# %%
name = "Abdurrehman"
age = 16
price = 34.88

print (type(name))
print(type (age))
print (type (price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### print

# %%
print ("Abdurrehman is my name.")
print("my age is 15.")

# %%
print(34+45)

# %%
name1 = "AJ"
name2 = 'AJ'
name3 = '''AJ'''

print (name1)
print (name2)
print (name3 )
# Out:
# AJ
# AJ
# AJ

# %%
a=9
b=9

c=a+b

print(c)
# Out:
# 18

# %%
a=int(input("Enter the first number :"))
b=int(input("Enter the second number :"))

# addition
c=a+b

print(c)
# Out:
# Enter the first number :9
# Enter the second number :9
# 18

# %%
a = int (input("enter the 1st value:"))
b = int (input("enter the 2nd value:"))
c = int (input("enter the 3nd value:"))
Sub = a-b-c
print (Sub)
# Out:
# enter the 1st value:12
# enter the 2nd value5
# enter the 3nd value6
# 1

# %%
a = int (input("enter your first value:"))
b = int (input("enter your second value:"))
c = int (input("enter your third value:"))
d = int (input("enter your forth value:"))
Mlti = a*b*c*d

print ("Multiply the number :",Mlti)
# Out:
# enter your first value:85
# enter your second value:89
# enter your third value:58
# enter your forth value:45
# Multi 19744650
